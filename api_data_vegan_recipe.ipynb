# %%
# import packages
import requests
import json
import pandas as pd
import pickle
import time
import os

# %%
# Get acces API
url = "https://api.edamam.com/api/recipes/v2"

api_id = os.environ['APP_ID']
api_key = os.environ['APP_KEY'] 

headers = {api_id, api_key}

querystring = {"type": "public", "q":"vegan", "app_id": api_id, "app_key": api_key}

response = requests.get(url, headers={"Authorization": api_key}, params=querystring)

# %%
json_response = json.loads(response.text.replace('null', '"None"').replace('True','"True"').replace('False','"False"'))

# %%
recipe_request = json_response

# %%
still_some_data = True
next_url=url

# %%
rec_dic = {}
count = 0 
df_list = []
while still_some_data:
    response = requests.get(next_url, headers={"Authorization": api_key}, params=querystring)
    try: 
      response.json()
    except:
      still_some_data = False
    try:
      recipe_request = response.json()
    except:
      print('headersize: ', print(len(next_url)))
      print(response.text) 
    time.sleep(6)
    
    try:
        print(f'Getting data for '+str(recipe_request['to']))
    except json.decoder.JSONDecodeError:
        print("There was a problem accessing the equipment data.")
        
    if recipe_request['to']==recipe_request['count']:
        still_some_data=False
    if recipe_request['to']> recipe_request['count']:
        still_some_data = False 
        
    next_url = recipe_request['_links']['next']['href']

    
    for idx, recipe in enumerate(recipe_request['hits']):
      count+=1
      if (recipe["recipe"]["mealType"][0]== 'lunch/dinner'):
        # print(recipe["recipe"]["label"])
        df_list.append([recipe["recipe"]["label"], \
            str(round(recipe['recipe']["totalNutrients"]['PROCNT']['quantity'], 2))+" g", \
            str(round(recipe['recipe']["totalNutrients"]['CHOCDF']['quantity'], 2))+" g",\
            str(round(recipe['recipe']["totalNutrients"]['FAT']['quantity'], 2))+" g"])
# Out:
# Getting data for 20
# Getting data for 40
# Getting data for 60
# Getting data for 80
# Getting data for 100
# Getting data for 120
# Getting data for 140
# Getting data for 160
# Getting data for 180
# Getting data for 200
# Getting data for 220
# Getting data for 240
# Getting data for 260
# Getting data for 280
# Getting data for 300
# Getting data for 320
# Getting data for 340
# Getting data for 360
# Getting data for 380
# Getting data for 400
# Getting data for 420
# Getting data for 440
# Getting data for 460
# Getting data for 480
# Getting data for 500
# Getting data for 520
# Getting data for 540
# Getting data for 560
# Getting data for 580
# Getting data for 600
# Getting data for 620
# Getting data for 640
# Getting data for 660
# Getting data for 680
# Getting data for 700
# Getting data for 720
# Getting data for 740
# Getting data for 760
# Getting data for 780
# Getting data for 800
# Getting data for 820
# Getting data for 840
# Getting data for 860
# Getting data for 880
# Getting data for 900
# Getting data for 920
# Getting data for 940
# Getting data for 960
# Getting data for 980
# Getting data for 1000
# Getting data for 1020
# Getting data for 1040
# Getting data for 1060
# Getting data for 1080
# Getting data for 1100
# Getting data for 1120
# Getting data for 1140
# Getting data for 1160
# Getting data for 1180
# Getting data for 1200
# Getting data for 1220
# Getting data for 1240
# Getting data for 1260
# Getting data for 1280
# Getting data for 1300
# Getting data for 1320
# Getting data for 1340
# Getting data for 1360
# Getting data for 1380
# Getting data for 1400
# Getting data for 1420
# Getting data for 1440
# Getting data for 1460
# Getting data for 1480
# Getting data for 1500
# Getting data for 1520
# Getting data for 1540
# Getting data for 1560
# Getting data for 1580
# Getting data for 1600
# Getting data for 1620
# Getting data for 1640
# Getting data for 1660
# Getting data for 1680
# Getting data for 1700
# Getting data for 1720
# Getting data for 1740
# Getting data for 1760
# Getting data for 1780
# Getting data for 1800
# Getting data for 1820
# Getting data for 1840
# Getting data for 1860
# Getting data for 1880
# Getting data for 1900
# Getting data for 1920
# Getting data for 1940
# Getting data for 1960
# Getting data for 1980
# 7819
# headersize:  None
# <!doctype html><html lang="en"><head><title>HTTP Status 400 – Bad Request</title><style type="text/css">body {font-family:Tahoma,Arial,sans-serif;} h1, h2, h3, b {color:white;background-color:#525D76;} h1 {font-size:22px;} h2 {font-size:16px;} h3 {font-size:14px;} p {font-size:12px;} a {color:black;} .line {height:1px;background-color:#525D76;border:none;}</style></head><body><h1>HTTP Status 400 – Bad Request</h1><hr class="line" /><p><b>Type</b> Exception Report</p><p><b>Message</b> Request header is too large</p><p><b>Description</b> The server cannot or will not process the request due to something that is perceived to be a client error (e.g., malformed request syntax, invalid request message framing, or deceptive request routing).</p><p><b>Exception</b></p><pre>java.lang.IllegalArgumentException: Request header is too large
# 	org.apache.coyote.http11.Http11InputBuffer.fill(Http11InputBuffer.java:779)
# 	org.apache.coyote.http11.Http11InputBuffer.parseHeader(Http11InputBuffer.java:946)
# 	org.apache.coyote.http11.Http11InputBuffer.parseHeaders(Http11InputBuffer.java:593)
# 	org.apache.coyote.http11.Http11Processor.service(Http11Processor.java:284)
# 	org.apache.coyote.AbstractProcessorLight.process(AbstractProcessorLight.java:65)
# 	org.apache.coyote.AbstractProtocol$ConnectionHandler.process(AbstractProtocol.java:893)
# 	org.apache.tomcat.util.net.NioEndpoint$SocketProcessor.doRun(NioEndpoint.java:1707)
# 	org.apache.tomcat.util.net.SocketProcessorBase.run(SocketProcessorBase.java:49)
# 	java.base&#47;java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1136)
# 	java.base&#47;java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
# 	org.apache.tomcat.util.threads.TaskThread$WrappingRunnable.run(TaskThread.java:61)
# 	java.base&#47;java.lang.Thread.run(Thread.java:833)
# </pre><p><b>Note</b> The full stack trace of the root cause is available in the server logs.</p><hr class="line" /><h3>Apache Tomcat/9.0.44</h3></body></html>
# Getting data for 1980

# %%
print(df_list)
print(len(df_list))
# Out:
# [['Spiked Vegan Eggnog', '46.36 g', '84.52 g', '42.61 g'], ['Vegan Cucumber Tea Sandwiches', '41.73 g', '143.91 g', '73.88 g'], ['Vegan Broccoli Soup Recipe', '103.83 g', '82.54 g', '139.3 g'], ['Baked Vegan Mac and Cheese Recipe', '140.19 g', '524.38 g', '221.29 g'], ['Vegan Nachos', '73.05 g', '266.38 g', '166.64 g'], ['The Best Vegan Breakfast Sandwich', '143.13 g', '208.42 g', '189.86 g'], ['{Vegan} Peanut Butter & Honey Muffins recipes', '29.53 g', '168.46 g', '59.83 g'], ['Vegan Pots de Crème', '45.25 g', '106.45 g', '98.01 g'], ['Vegan tiffin', '60.38 g', '272.18 g', '287.22 g'], ['Vegan Stovetop Lasagna', '124.77 g', '512.21 g', '147.15 g'], ['Vegan Italian Cold Cut
cream', '34.96 g', '284.85 g', '220.65 g'], ['Vegan Ginger Sticky Date Pudding & Cardamom Toffee', '43.95 g', '859.11 g', '287.58 g'], ['‘Cheesy’ vegan scones', '68.49 g', '279.16 g', '49.72 g'], ['Vegan Mushroom Stroganoff', '50.67 g', '221.8 g', '68.92 g'], ['Vegan Fig Galette', '52.72 g', '880.99 g', '346.35 g'], ['Vegan fry-up', '100.27 g', '167.06 g', '279.46 g'], ['Traditional Vegan Caesar Salad', '46.34 g', '126.68 g', '66.66 g'], ['Vegan Mushroom Bolognese', '57.26 g', '229.43 g', '36.96 g'], ['Vegan White Peach Mug Cobbler With Cardamom', '5.51 g', '70.81 g', '16.13 g'], ['Easy vegan tacos', '26.13 g', '153.72 g', '15.67 g'], ['Gluten-Free Walnut & Portobello Mushroom Vegan Burgers', '34.55 g', '97.14 g', '30.74 g'], ['Vegan Cauliflower Alfre ...
# 1522

# %%
for elem in reversed(df_list):
  print(elem)

# %%
df = pd.DataFrame(df_list, columns = ['Recipe_name', 'Protein', 'Carbs', 'Fat'])

print(df)
print(len(df['Recipe_name'].unique()))
# Out:
#                                    Recipe_name   Protein     Carbs       Fat
# 0                          Spiked Vegan Eggnog   46.36 g   84.52 g   42.61 g
# 1                Vegan Cucumber Tea Sandwiches   41.73 g  143.91 g   73.88 g
# 2                   Vegan Broccoli Soup Recipe  103.83 g   82.54 g   139.3 g
# 3            Baked Vegan Mac and Cheese Recipe  140.19 g  524.38 g  221.29 g
# 4                                 Vegan Nachos   73.05 g  266.38 g  166.64 g
# ...                                        ...       ...       ...       ...
# 1517  Vegan Parmesan-Crusted Cauliflower Wings   56.28 g   65.62 g   90.77 g
# 1518                          Vegan Spice Cake    34.4 g  551.66 g  193.42 g
# 1519                      Fudgy Vegan Brownies   28.65 g  364.77 g  168.68 g
# 1520           Vegan Spinach Pinwheels recipes   44.84 g   59.62 g   60.33 g
# 1521                Vegan Noodle Kugel recipes   60.29 g  469.33 g  108.76 g
#
# [1522 rows x 4 columns]
# 1469

# %%
# Save into CSV
df.to_csv('Vegan.csv', index = False)

# %%
# Or read pandas
pd.read_csv('Vegan.csv')
# Out:
#                                    Recipe_name   Protein     Carbs       Fat
# 0                          Spiked Vegan Eggnog   46.36 g   84.52 g   42.61 g
# 1                Vegan Cucumber Tea Sandwiches   41.73 g  143.91 g   73.88 g
# 2                   Vegan Broccoli Soup Recipe  103.83 g   82.54 g   139.3 g
# 3            Baked Vegan Mac and Cheese Recipe  140.19 g  524.38 g  221.29 g
# 4                                 Vegan Nachos   73.05 g  266.38 g  166.64 g
# ...                                        ...       ...       ...       ...
# 1517  Vegan Parmesan-Crusted Cauliflower Wings   56.28 g   65.62 g   90.77 g
# 1518                          Vegan Spice Cake    34.4 g  551.66 g  193.42 g
# 1519                      Fudgy Vegan Brownies   28.65 g  364.77 g  168.68 g
# 1520           Vegan Spinach Pinwheels recipes   44.84 g   59.62 g   60.33 g
# 1521                Vegan Noodle Kugel recipes   60.29 g  469.33 g  108.76 g
#
# [1522 rows x 4 columns]
